# %%
import pandas as pd

# %%
dataset=pd.read_csv("kidney_disease_test.csv")

# %%
dataset
# Out:
#       id   age     bp     sg   al   su       rbc        pc         pcc  \
# 0    209  19.0   70.0  1.020  0.0  0.0       NaN    normal  notpresent
# 1    280  47.0   80.0    NaN  NaN  NaN       NaN       NaN  notpresent
# 2     33  60.0  100.0  1.020  2.0  0.0  abnormal  abnormal  notpresent
# 3    210  59.0  100.0  1.015  4.0  2.0    normal    normal  notpresent
# 4     93  73.0  100.0  1.010  3.0  2.0  abnormal  abnormal     present
# ..   ...   ...    ...    ...  ...  ...       ...       ...         ...
# 115   60  67.0   90.0  1.020  1.0  0.0       NaN  abnormal     present
# 116   79  56.0   80.0  1.010  1.0  0.0       NaN    normal  notpresent
# 117  285  66.0   70.0  1.020  0.0  0.0    normal    normal  notpresent
# 118  305  41.0   80.0  1.020  0.0  0.0    normal    normal  notpresent
# 119  281  55.0   80.0  1.025  0.0  0.0    normal    normal  notpresent
#
#              ba  ...  hemo  pcv       wc   rc  htn   dm  cad  appet   pe  ane
# 0    notpresent  ...  11.5  NaN   6900.0  NaN   no   no   no   good   no   no
# 1    notpresent  ...  13.3   52   8100.0  5.2   no   no   no   good   no   no
# 2    notpresent  ...  10.1   29      NaN  NaN  yes   no   no   poor   no   no
# 3    notpresent  ...   7.3   20   9800.0  3.9  yes  yes  yes   good   no  yes
# 4    notpresent  ...   9.2   30   7000.0  3.2  yes  yes  yes   poor   no   no
# ..          ...  ...   ...  ...      ...  ...  ...  ...  ...    ...  ...  ...
# 115  notpresent  ...   NaN  NaN      NaN  NaN  yes   no   no   good   no   no
# 116  notpresent  ...  13.5   40  11800.0  5.0  yes  yes   no   poor  yes   no
# 117  notpresent  ...  16.0   41   5300.0  5.9   no   no   no   good   no   no
# 118  notpresent  ...  17.1   41   9100.0  5.2   no   no   no   good   no   no
# 119  notpresent  ...  15.5   41   9100.0  6.0   no   no   no   good   no   no
#
# [120 rows x 25 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 399 entries, 0 to 398
# Data columns (total 25 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             399 non-null    float64
#  1   bp              399 non-null    float64
#  2   sg              399 non-null    object
#  3   al              399 non-null    float64
#  4   su              399 non-null    float64
#  5   rbc             399 non-null    object
#  6   pc              399 non-null    object
#  7   pcc             399 non-null    object
#  8   ba              399 non-null    object
#  9   bgr             399 non-null    float64
#  10  bu              399 non-null    float64
#  11  sc              399 non-null    float64
#  12  sod             399 non-null    float64
#  13  pot             399 non-null    float64
#  14  hrmo            399 non-null    float64
#  15  pcv             399 non-null    float64
#  16  wc              399 non-null    float64
#  17  rc              399 non-null    float64
#  18  htn             399 non-null    object
#  19  dm              399 non-null    object
#  20  cad             399 non-null    object
#  21  appet           399 non-null    object
#  22  pe              399 non-null    object
#  23  ane             399 non-null    object
#  24  classification  399 non-null    object
# dtypes: float64(13), object(12)
# memory usage: 78.1+ KB

# %%
dataset.isnull()
# Out:
#         id    age     bp     sg     al     su    rbc     pc    pcc     ba  \
# 0    False  False  False  False  False  False   True  False  False  False
# 1    False  False  False   True   True   True   True   True  False  False
# 2    False  False  False  False  False  False  False  False  False  False
# 3    False  False  False  False  False  False  False  False  False  False
# 4    False  False  False  False  False  False  False  False  False  False
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 115  False  False  False  False  False  False   True  False  False  False
# 116  False  False  False  False  False  False   True  False  False  False
# 117  False  False  False  False  False  False  False  False  False  False
# 118  False  False  False  False  False  False  False  False  False  False
# 119  False  False  False  False  False  False  False  False  False  False
#
#      ...   hemo    pcv     wc     rc    htn     dm    cad  appet     pe    ane
# 0    ...  False   True  False   True  False  False  False  False  False  False
# 1    ...  False  False  False  False  False  False  False  False  False  False
# 2    ...  False  False   True   True  False  False  False  False  False  False
# 3    ...  False  False  False  False  False  False  False  False  False  False
# 4    ...  False  False  False  False  False  False  False  False  False  False
# ..   ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 115  ...   True   True   True   True  False  False  False  False  False  False
# 116  ...  False  False  False  False  False  False  False  False  False  False
# 117  ...  False  False  False  False  False  False  False  False  False  False
# 118  ...  False  False  False  False  False  False  False  False  False  False
# 119  ...  False  False  False  False  False  False  False  False  False  False
#
# [120 rows x 25 columns]

# %%
dataset.isnull().sum()
# Out:
# id        0
# age       4
# bp        3
# sg       11
# al       11
# su       11
# rbc      45
# pc       15
# pcc       0
# ba        0
# bgr      11
# bu        5
# sc        5
# sod      20
# pot      20
# hemo     13
# pcv      19
# wc       28
# rc       37
# htn       1
# dm        1
# cad       1
# appet     1
# pe        1
# ane       1
# dtype: int64

# %%
def quanQual(dataset):
    quan=[]
    qual=[]
    for columnname in dataset.columns:
            #print(columnname)
        if(dataset[columnname].dtype=='O'):
            #print("qual")
            qual.append(columnname)
        else:
           # print("quan")
            quan.append(columnname)
    return quan,qual

# %%
quan,qual=quanQual(dataset)

# %%
dataset[quan]
# Out:
#       id   age     bp     sg   al   su    bgr     bu    sc    sod  pot  hemo  \
# 0    209  19.0   70.0  1.020  0.0  0.0    NaN    NaN   NaN    NaN  NaN  11.5
# 1    280  47.0   80.0    NaN  NaN  NaN   93.0   33.0   0.9  144.0  4.5  13.3
# 2     33  60.0  100.0  1.020  2.0  0.0  140.0   55.0   2.5    NaN  NaN  10.1
# 3    210  59.0  100.0  1.015  4.0  2.0  255.0  132.0  12.8  135.0  5.7   7.3
# 4     93  73.0  100.0  1.010  3.0  2.0  295.0   90.0   5.6  140.0  2.9   9.2
# ..   ...   ...    ...    ...  ...  ...    ...    ...   ...    ...  ...   ...
# 115   60  67.0   90.0  1.020  1.0  0.0  141.0   66.0   3.2  138.0  6.6   NaN
# 116   79  56.0   80.0  1.010  1.0  0.0  165.0   55.0   1.8    NaN  NaN  13.5
# 117  285  66.0   70.0  1.020  0.0  0.0   94.0   19.0   0.7  135.0  3.9  16.0
# 118  305  41.0   80.0  1.020  0.0  0.0  122.0   25.0   0.8  138.0  5.0  17.1
# 119  281  55.0   80.0  1.025  0.0  0.0  130.0   50.0   1.2  147.0  5.0  15.5
#
#           wc   rc
# 0     6900.0  NaN
# 1     8100.0  5.2
# 2        NaN  NaN
# 3     9800.0  3.9
# 4     7000.0  3.2
# ..       ...  ...
# 115      NaN  NaN
# 116  11800.0  5.0
# 117   5300.0  5.9
# 118   9100.0  5.2
# 119   9100.0  6.0
#
# [120 rows x 14 columns]

# %%
import numpy as np
from sklearn.impute import SimpleImputer
imp=SimpleImputer(missing_values=np.nan,strategy='mean')
imp.fit(dataset[quan])
noMissing_values=imp.transform(dataset[quan])

# %%
imp
# Out:
# SimpleImputer()

# %%
noMissing_values=pd.DataFrame(noMissing_values,columns=quan)

# %%
noMissing_values
# Out:
#         id   age     bp        sg   al        su         bgr          bu  \
# 0    209.0  19.0   70.0  1.020000  0.0  0.000000  143.165138   58.447826
# 1    280.0  47.0   80.0  1.017339  1.0  0.477064   93.000000   33.000000
# 2     33.0  60.0  100.0  1.020000  2.0  0.000000  140.000000   55.000000
# 3    210.0  59.0  100.0  1.015000  4.0  2.000000  255.000000  132.000000
# 4     93.0  73.0  100.0  1.010000  3.0  2.000000  295.000000   90.000000
# ..     ...   ...    ...       ...  ...       ...         ...         ...
# 115   60.0  67.0   90.0  1.020000  1.0  0.000000  141.000000   66.000000
# 116   79.0  56.0   80.0  1.010000  1.0  0.000000  165.000000   55.000000
# 117  285.0  66.0   70.0  1.020000  0.0  0.000000   94.000000   19.000000
# 118  305.0  41.0   80.0  1.020000  0.0  0.000000  122.000000   25.000000
# 119  281.0  55.0   80.0  1.025000  0.0  0.000000  130.000000   50.000000
#
#             sc     sod    pot       hemo            wc        rc
# 0     3.226957  138.11  4.358  11.500000   6900.000000  4.709639
# 1     0.900000  144.00  4.500  13.300000   8100.000000  5.200000
# 2     2.500000  138.11  4.358  10.100000   8518.478261  4.709639
# 3    12.800000  135.00  5.700   7.300000   9800.000000  3.900000
# 4     5.600000  140.00  2.900   9.200000   7000.000000  3.200000
# ..         ...     ...    ...        ...           ...       ...
# 115   3.200000  138.00  6.600  12.514953   8518.478261  4.709639
# 116   1.800000  138.11  4.358  13.500000  11800.000000  5.000000
# 117   0.700000  135.00  3.900  16.000000   5300.000000  5.900000
# 118   0.800000  138.00  5.000  17.100000   9100.000000  5.200000
# 119   1.200000  147.00  5.000  15.500000   9100.000000  6.000000
#
# [120 rows x 14 columns]
